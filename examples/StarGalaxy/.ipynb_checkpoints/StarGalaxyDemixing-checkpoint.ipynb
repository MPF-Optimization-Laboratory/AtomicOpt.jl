# %%
push!(LOAD_PATH, "/home/zhenan/Github/AtomicOpt.jl")
using AtomicOpt
using Plots
using Images
using LinearAlgebra
using SparseArrays
using FFTW
using LinearMaps

# %% [markdown]
# ## Load data

# %%
xs = Vector{Float64}()
xd = Vector{Float64}()
b = Vector{Float64}()
m = 0
n = 0
ks = 0
kd = 0
lines = readlines("./StarGalaxyData.txt", keep=true)
for line in lines
    info = split(line)
    if length(info) ≥ 1
        if info[1] == "xs"
            for s in info[3:end]
                push!(xs, parse(Float64, s))
            end
        elseif info[1] == "xd"
            for s in info[3:end]
                push!(xd, parse(Float64, s))
            end
        elseif info[1] == "b"
            for s in info[3:end]
                push!(b, parse(Float64, s))
            end
        elseif info[1] == "ks"
            ks = parse(Int64, info[3])
        elseif info[1] == "kd"
            kd = parse(Int64, info[3])
        elseif info[1] == "m"
            m = parse(Int64, info[3])
        elseif info[1] == "n"
            n = parse(Int64, info[3])
        end
    end
end

# %% [markdown]
# ## Construct atomic sets

# %%
τs = gauge(OneBall(n*m), xs)
As = τs*OneBall(n*m; maxrank = ks)
τd = gauge(OneBall(n*m), dct(xd))
Q = LinearMap(p->idct(p), q->dct(q), n*m, n*m)
Ad = τd*Q*OneBall(n*m; maxrank = kd)
A = As + Ad
# Out:
# atomic set  : Sum of atomic sets
# description : A₁ + A₂ + ⋯
# parameters  : 2 sets; n = 361201

# %% [markdown]
# ## Solve demixing problem

# %%
sol = level_set(I(m*n), b, A, tol = 1e-1, maxIts=5000)
# Out:
#   -------------------------------------------------------------------------
#   Polar Level Set Method
#   -------------------------------------------------------------------------
#   number of variables     361201         number of constraints  361201
#   feasibility tolerance  9.78e+00         α                    0.00e+00
#   max iterations             500
#   -------------------------------------------------------------------------
#   Major      Minor        u-α        ℓ-α        gap          τ         infeas-α  Subproblem
#       1          1   1.38e+04   9.16e+03   4.69e+03   4.86e-02       4.69e+03   suboptimal
#       2          4   2.18e+03   6.56e+02   1.53e+03   6.70e-02       4.69e+03   suboptimal
#       3          3   1.75e+03   3.10e+02   1.44e+03   8.25e-02       4.69e+03   suboptimal
#       4          2   1.57e+03   6.04e+02   9.70e+02   9.16e-02       4.69e+03   suboptimal
#       5          7   1.29e+03   3.03e+02   9.83e+02   1.18e-01       4.69e+03   suboptimal
#       6          9   1.18e+03   7.68e+01   1.10e+03   1.40e-01       4.69e+03   suboptimal
#       7          5   1.14e+03   3.78e+01   1.10e+03   1.48e-01       4.69e+03   suboptimal
#       8          3   1.12e+03   1.10e+01   1.11e+03   1.52e-01       4.69e+03   suboptimal
#       9          1   1.11e+03   1.04e+01   1.10e+03   1.53e-01       4.69e+03   suboptimal
#      10          2   1.09e+03   3.14e+01   1.06e+03   1.54e-01       4.69e+03   suboptimal
#      11          3   1.07e+03   2.74e+01   1.05e+03   1.58e-01       4.69e+03   suboptimal
#      12          4   1.05e+03   2.51e+01   1.02e+03   1.62e-01       4.69e+03   suboptimal
#      13          4   1.01e+03   3.66e+01   9.78e+02   1.65e-01       4.69e+03   suboptimal
e-5, 4.7371700990176785e-5, 9.124798778453257e-5, 2.4736942929592607e-5, 8.595445180282327e-5  …  2.1460611983321074e-6, 1.2476295650240894e-5, 7.249197417272371e-6, -5.282608229486554e-6, 9.157702593546318e-7, -2.5485435240704534e-6, 3.673167619049335e-6, 3.219090882393758e-5, -1.3716691251276743e-5, 4.18418255413383e-6], 123.79334612647678, 123.79334612647678, [0.023529107329568776, 0.0234564184210755, 0.02543302127382513, 0.03063849529250481, 0.03511709088948138, 0.03687939704831194, 0.039502514739353234, 5.007652278954389e-9, 0.04475372502479062, 0.04171475633310141  …  0.036315549328214354, 0.03713705375034178, 0.0391554828439786, 0.043055463703571495, 0.042853339992376185, 0.03666200951878203, 0.026433437929246226, 0.01688807992884603, 0.014294727334744087, 0.01396505837670609])

# %% [markdown]
# ## Plot

# %%
x1 = sol.F.faces[1] * sol.c[1:ks]
colorview(Gray, reshape(x1, m, n))
# Out:
# 601×601 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.114267)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0772365)  Gray{Float64}(0.280027)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.225709)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  ⋮                                                  ⋱  ⋮
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)          Gray{Float64}(0.0)
#  Gray{Float64}(0.0)        Gray{Float64}(0.0)       …  Gray{Float64}(0.0)

# %%
x2 = sol.F.faces[2] * sol.c[ks+1:end]
colorview(Gray, reshape(x2, m, n))
# Out:
# 601×601 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.00815769)  …  Gray{Float64}(0.0106174)
#  Gray{Float64}(0.00809416)     Gray{Float64}(0.0127914)
#  Gray{Float64}(0.00857395)     Gray{Float64}(0.0135876)
#  Gray{Float64}(0.010122)       Gray{Float64}(0.0116921)
#  Gray{Float64}(0.0126068)      Gray{Float64}(0.00865919)
#  Gray{Float64}(0.0154616)   …  Gray{Float64}(0.00732615)
#  Gray{Float64}(0.0182834)      Gray{Float64}(0.00872764)
#  Gray{Float64}(0.0207635)      Gray{Float64}(0.0110582)
#  Gray{Float64}(0.0220543)      Gray{Float64}(0.0119896)
#  Gray{Float64}(0.0211196)      Gray{Float64}(0.0114956)
#  Gray{Float64}(0.0184273)   …  Gray{Float64}(0.0115881)
#  Gray{Float64}(0.0165937)      Gray{Float64}(0.0133674)
#  Gray{Float64}(0.0181055)      Gray{Float64}(0.0153215)
#  ⋮                          ⋱  ⋮
#  Gray{Float64}(0.0187546)      Gray{Float64}(0.0130031)
#  Gray{Float64}(0.0180379)   …  Gray{Float64}(0.011937)
#  Gray{Float64}(0.0180956)      Gray{Float64}(0.0123459)
#  Gray{Float64}(0.0174414)      Gray{Float64}(0.0131006)
#  Gray{Float64}(0.01581)        Gray{Float64}(0.0122494)
#  Gray{Float64}(0.014058)       Gray{Float64}(0.00992675)
#  Gray{Float64}(0.0129234)   …  Gray{Float64}(0.00851934)
#  Gray{Float64}(0.0122845)      Gray{Float64}(0.00967587)
#  Gray{Float64}(0.0115409)      Gray{Float64}(0.0120848)
#  Gray{Float64}(0.010482)       Gray{Float64}(0.0129863)
#  Gray{Float64}(0.00954472)     Gray{Float64}(0.0114824)
#  Gray{Float64}(0.0091053)   …  Gray{Float64}(0.0095281)
